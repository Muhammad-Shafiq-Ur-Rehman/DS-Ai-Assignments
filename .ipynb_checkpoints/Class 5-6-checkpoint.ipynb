# %% [markdown]
# <h1>Class 5</h1>

# %%
quiz=[{"S.No":1,
      "Question": "What is the Capital of Pakistan?",
      "Options":["Karachi","Islamabad","Lahore","Quetta"],
      "Answer":"Islamabad"}]
type(quiz)
# Out:
# list

# %%
Q2= {"S.No":2,
      "Question": "What is national Sport Of Pakistan?",
      "Options":["Cricket","Football","Hockey","Baseball"],
      "Answer":"Hockey"}

# %%
quiz.append(Q2)
quiz.append(Q3)
quiz.append(Q4)

# %%
Q3={"S.No":3,
      "Question": "Independence Year of Pakistan",
      "Options":["1947","1950","1948","1951"],
      "Answer":"1947"}

# %%
quiz
# Out:
# [{'S.No': 1,
#   'Question': 'What is the Capital of Pakistan?',
#   'Options': ['Karachi', 'Islamabad', 'Lahore', 'Quetta'],
#   'Answer': 'Islamabad'},
#  {'S.No': 2,
#   'Question': 'What is national Sport Of Pakistan?',
#   'Options': ['Cricket', 'Football', 'Hockey', 'Baseball'],
#   'Answer': 'Hockey'},
#  {'S.No': 3,
#   'Question': 'Independence Year of Pakistan',
#   'Options': ['1947', '1950', '1948', '1951'],
#   'Answer': '1947'},
#  {'S.No': 4,
#   'Question': 'Orange is a',
#   'Options': ['Color', 'Fruit', 'Both', 'Nothing'],
#   'Answer': 'Both'}]

# %%
Q4={"S.No":4,
      "Question": "Orange is a",
      "Options":["Color","Fruit","Both","Nothing"],
      "Answer":"Both"}

# %%
for i in quiz:
        print(f"{i} \n")
# Out:
# {'S.No': 1, 'Question': 'What is the Capital of Pakistan?', 'Options': ['Karachi', 'Islamabad', 'Lahore', 'Quetta'], 'Answer': 'Islamabad'}
#
# {'S.No': 2, 'Question': 'What is national Sport Of Pakistan?', 'Options': ['Cricket', 'Football', 'Hockey', 'Baseball'], 'Answer': 'Hockey'}
#
# {'S.No': 3, 'Question': 'Independence Year of Pakistan', 'Options': ['1947', '1950', '1948', '1951'], 'Answer': '1947'}
#
# {'S.No': 4, 'Question': 'Orange is a', 'Options': ['Color', 'Fruit', 'Both', 'Nothing'], 'Answer': 'Both'}

# %%
print(quiz[1]["Options"])
print(quiz[1]["Answer"])
# Out:
# ['Cricket', 'Football', 'Hockey', 'Baseball']
# Hockey

# %%
score = 0
for q in quiz:
    ans= str(q["S.No"]) + " " + q["Question"] + "\n\n" + "1 "+ q["Options"][0] +"\n2 " + q["Options"][1] +"\n3 "+ q["Options"][2] +"\n4 "+ q["Options"][3] + "\n\n"
    answer= input(ans)
    if answer == q["Answer"]:
        score +=1
print(f"Score is {score}")
# Out:
# 1 What is the Capital of Pakistan?
#
# 1 Karachi
# 2 Islamabad
# 3 Lahore
# 4 Quetta
#
#  Islamabad
# 2 What is national Sport Of Pakistan?
#
# 1 Cricket
# 2 Football
# 3 Hockey
# 4 Baseball
#
#  Hockey
# 3 Independence Year of Pakistan
#
# 1 1947
# 2 1950
# 3 1948
# 4 1951
#
#  1948
# 4 Orange is a
#
# 1 Color
# 2 Fruit
# 3 Both
# 4 Nothing
#
#  Both
# Score is 3

# %%
score
# Out:
# 4

# %%
def addition():
    a=5
    b=10
    print(f"Addition is {a+b}")
addition()
# Out:
# Addition is 15

# %%
# Out:
# Hello

# %% [markdown]
# <h1>Class 6</h1>

# %%
def info(*x,**y):
    print("Positional Arguments :", x)
    print("Keyword Arguments :", y)

info("Shafiq","24","Student",Emails=["m.**rehman@outlook.com","fa**bece@gmail.com"],Contacts=["0343124****","03140302***"])
# Out:
# Positional Arguments : ('Shafiq', '24', 'Student')
# Keyword Arguments : {'Emails': ['m.**rehman@outlook.com', 'fa**bece@gmail.com'], 'Contacts': ['0343124****', '03140302***']}

# %%
Ec_Store_Orders = [
    {"order_id": 1, "customer_name": "Ali", "total_amount": 120, "status": "Completed"},
    {"order_id": 2, "customer_name": "Raheel", "total_amount": 80, "status": "Pending"},
    {"order_id": 3, "customer_name": "Sana", "total_amount": 150, "status": "Completed"},
    {"order_id": 4, "customer_name": "Sajid", "total_amount": 95, "status": "Completed"},
    {"order_id": 5, "customer_name": "Alizy", "total_amount": 200, "status": "Pending"},
    {"order_id": 6, "customer_name": "javaid", "total_amount": 85, "status": "Completed"},
    {"order_id": 7, "customer_name": "Talha", "total_amount": 150, "status": "Pending"},
    {"order_id": 8, "customer_name": "Naveed", "total_amount": 200, "status": "Completed"},
]

# %%
list_comp = [i["total_amount"] >= 100 and i["status"]=="Completed" for i in Ec_Store_Orders]
print(list_comp)
# Out:
# [True, False, True, False, False, False, False, True]

# %%
list_comp = [i for i in Ec_Store_Orders if i["total_amount"] >= 100 and i["status"]=="Completed" ]
print(list_comp)
# Out:
# [{'order_id': 1, 'customer_name': 'Ali', 'total_amount': 120, 'status': 'Completed'}, {'order_id': 3, 'customer_name': 'Sana', 'total_amount': 150, 'status': 'Completed'}, {'order_id': 8, 'customer_name': 'Naveed', 'total_amount': 200, 'status': 'Completed'}]

# %%
list_comp = [i["order_id"] for i in Ec_Store_Orders if i["total_amount"] >= 100 and i["status"]=="Completed" ]
print(list_comp)
# Out:
# [1, 3, 8]

# %%
high_value_order_ids = [i["order_id"] for i in Ec_Store_Orders if i["total_amount"] >= 100 and i["status"] == "Completed"]

print(high_value_order_ids)
# Out:
# [1, 3, 8]

# %%
high_value_order_ids = list(map(lambda order: order,filter(
            lambda order: order["total_amount"] >= 100 and order["status"] == "Completed",
            Ec_Store_Orders)))

print(high_value_order_ids)
# Out:
# [{'order_id': 1, 'customer_name': 'Ali', 'total_amount': 120, 'status': 'Completed'}, {'order_id': 3, 'customer_name': 'Sana', 'total_amount': 150, 'status': 'Completed'}, {'order_id': 8, 'customer_name': 'Naveed', 'total_amount': 200, 'status': 'Completed'}]

# %%
a=int(input("enter value"))
print(4/2)
try:
    print(0/a)
except:
    print("Error")
# Out:
# enter value 12
# 2.0
# 0.0
