# %% [markdown]
# <h2>Q1. Load the dataset and display first 5 rows?</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("dataset.csv")
df.head()
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# ...

# %% [markdown]
# <h2>Q2. Display dataset shape and column names?</h2>

# %%
df.shape
# Out:
# (1474, 13)

# %% [markdown]
# <h2>Q3. Check data types of all columns?</h2>

# %%
df.dtypes
# Out:
# Number of clicks on similar products                             int64
# Number of similar products purchased so far                      int64
# Average rating given to similar products                       float64
# Gender                                                          object
# Median purchasing price (in rupees)                              int64
# Rating of the product                                          float64
# Brand of the product                                            object
# Customer review sentiment score (overall)                      float64
# Price of the product                                             int64
# Holiday                                                         object
# Season                                                          object
# Geographical locations                                          object
# Probability for the product to be recommended to the person    float64
# dtype: object

# %% [markdown]
# Q4. Identify missing values in each column?

# %% [markdown]
# <h2>Q5. Handle missing values?</h2>

# %%
df.isnull().sum()
# Out:
# Number of clicks on similar products                           0
# Number of similar products purchased so far                    0
# Average rating given to similar products                       0
# Gender                                                         0
# Median purchasing price (in rupees)                            0
# Rating of the product                                          0
# Brand of the product                                           0
# Customer review sentiment score (overall)                      0
# Price of the product                                           0
# Holiday                                                        0
# Season                                                         0
# Geographical locations                                         0
# Probability for the product to be recommended to the person    0
# dtype: int64

# %% [markdown]
# <h2>Q6. Check and remove duplicate rows?</h2>

# %%
df.duplicated().sum()
# Out:
# np.int64(456)

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (1018, 13)

# %% [markdown]
# <h2>Q7. Generate summary statistics?</h2>

# %%
df.describe()
# Out:
#        Number of clicks on similar products  \
# count                           1018.000000
# mean                              21.397839
# std                               12.103449
# min                                0.000000
# 25%                               11.000000
# 50%                               20.000000
# 75%                               31.000000
# max                               55.000000
#
#        Number of similar products purchased so far  \
# count                                  1018.000000
# mean                                      9.017682
# std                                       5.740169
# min                                       0.000000
# 25%                                       4.000000
# 50%                                       8.000000
# 75%                                      14.000000
# max                                      24.000000
#
#        Average rating given to similar products  \
# ...

# %% [markdown]
# <h2>Q8. Calculate the average of 'Price of the product'?</h2>

# %%
df["Price of the product"].unique()
# Out:
# array([  200,   300,  1000,   700,   900,   400,   600,   500,   100,
#          800, 10000,  2000,  1800,  1400,   180,  1900,  2500,   250,
#         1300,    90,  4500,  2700,  2800,   550,   190,   950,   280,
#         9000,  3000,  4000,  6000,  8000,  7000,  5000,  1200,  1500,
#         1100,  1600,  1700,   170,   750,   430])

# %%
df["Price of the product"].value_counts().head(12)
# Out:
# Price of the product
# 800      134
# 700      107
# 900       88
# 600       84
# 500       83
# 300       74
# 400       71
# 200       70
# 1000      56
# 100       36
# 10000     24
# 1200      24
# Name: count, dtype: int64

# %%
df["Price of the product"].min()
# Out:
# 90

# %%
df["Price of the product"].max()
# Out:
# 10000

# %%
df["Price of the product"].median()
# Out:
# 700.0

# %%
df["Price of the product"].mean()
# Out:
# np.float64(1334.9214145383105)

# %%
df["Price of the product"].mode()
# Out:
# 0    800
# Name: Price of the product, dtype: int64

# %% [markdown]
# <h2>Q9. Find max and min of 'Median purchasing price (in rupees)'?</h2>

# %%
df['Median purchasing price (in rupees)'].min()
# Out:
# 100

# %%
df['Median purchasing price (in rupees)'].max()
# Out:
# 19000

# %% [markdown]
# <h2>Q10. Value counts of 'Brand of the product'?</h2>

# %%
df['Brand of the product'].value_counts()
# Out:
# Brand of the product
# Wildcraft                          74
# Manyavar Mohey                     58
# Pepperfry                          55
# Flying Machine                     52
# Patanjali Ayurved (Health Care)    50
# Lee                                46
# Lakme Ayurveda                     45
# Wakefit                            41
# Johnson & Johnson                  40
# Khadi Essentials                   34
# Pepe Jeans London                  33
# Kama Ayurveda                      32
# Max                                29
# PUMA                               25
# Head Hunters                       24
# Himalaya Liv.52                    24
# Sugar Cosmetics                    24
# Fastrack                           22
# The Moms Co.                       22
# Dettol                             21
# Urban Ladder                       20
# SleepyCat                          20
# AmazonBasics                       17
# Allen Solly Woman                  16
# ...

# %% [markdown]
# <h2>Q11. Sort data by 'Price of the product'?</h2>

# %%
df.sort_values('Price of the product',ascending=False)
# Out:
#       Number of clicks on similar products  \
# 920                                     47
# 1404                                    20
# 1431                                    17
# 851                                     45
# 1444                                    14
# ...                                    ...
# 37                                      18
# 84                                      10
# 764                                     39
# 788                                     34
# 752                                     40
#
#       Number of similar products purchased so far  \
# 920                                            20
# 1404                                            7
# 1431                                            6
# 851                                            18
# 1444                                            5
# ...                                           ...
# 37                                              8
# ...

# %% [markdown]
# <h2>Q12. Filter data where rating > 4?</h2>

# %%
df[df['Rating of the product'] > 4]
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 2                                       25
# 4                                       18
# 6                                       38
# 9                                       10
# ...                                    ...
# 1467                                    43
# 1468                                    21
# 1470                                    37
# 1471                                    22
# 1472                                    40
#
#       Number of similar products purchased so far  \
# 0                                               4
# 2                                              10
# 4                                               5
# 6                                              15
# 9                                               4
# ...                                           ...
# 1467                                           14
# ...

# %% [markdown]
# <p><h2>Q13. Create new column 'Price Difference'?</h2></p>By using (Price of the product - Median Purchasing Price)

# %%
df["Price Difference"] = df['Price of the product'] - df['Median purchasing price (in rupees)']

# %%
df.head()
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# ...

# %% [markdown]
# <h2>Q14. GroupBy average price by Gender?</h2>

# %%
df.groupby('Gender')['Price of the product'].mean()
# Out:
# Gender
# female     783.638171
# male      1873.359223
# Name: Price of the product, dtype: float64

# %%
df.groupby('Gender')['Price of the product'].median()
# Out:
# Gender
# female    700.0
# male      800.0
# Name: Price of the product, dtype: float64

# %% [markdown]
# <h2>Q15. Create histogram Price of the product?</h2>

# %%
plt.hist(df['Price of the product'],bins=20,edgecolor='black',color='green',label="Price Distribution")
# Out:
# (array([345., 472.,  75.,  22.,   2.,   9.,   0.,   3.,   3.,   8.,   0.,
#          23.,   0.,   2.,   0.,  16.,   0.,  14.,   0.,  24.]),
#  array([   90. ,   585.5,  1081. ,  1576.5,  2072. ,  2567.5,  3063. ,
#          3558.5,  4054. ,  4549.5,  5045. ,  5540.5,  6036. ,  6531.5,
#          7027. ,  7522.5,  8018. ,  8513.5,  9009. ,  9504.5, 10000. ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df['Price of the product'],bins=20,edgecolor='black',color='green',label="Price Distribution")
plt.xlabel("Value", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.title("Styled Histogram with plt.hist()", fontsize=14)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)

# %% [markdown]
# • Write 4 to 5 lines explaining:
# • Which factor influences recommendations the most?
# • What changes did you observe after cleaning the data?
# • One interesting pattern you found.

# %%
df['Rating of the product'].value_counts().head(10)
# Out:
# Rating of the product
# 4.8    117
# 4.9     84
# 4.7     80
# 4.6     62
# 5.0     58
# 4.5     54
# 4.4     42
# 3.8     35
# 4.3     34
# 3.5     32
# Name: count, dtype: int64

# %% [raw]
# 1) The more the rating, more purchases.
